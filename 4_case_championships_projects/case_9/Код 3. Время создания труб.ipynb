# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/Все оставшееся/Axenix/Обработка данных с временем/ОДПП. Очищенные с подсчитанными данными.csv')
data.head()
# Out:
#    Номер заказа  Номер трубы       Категория  \
# 0           135     15012396  Стальные трубы
# 1           135     15012403  Стальные трубы
# 2           135     15012410  Стальные трубы
# 3           135     15012417  Стальные трубы
# 4           135     15012424  Стальные трубы
#
#   Время принятия на Электросварочный стан_plan  \
# 0                      2024-03-01 09:00:10.000
# 1                      2024-03-01 09:01:20.000
# 2                      2024-03-01 09:02:30.000
# 3                      2024-03-01 09:03:40.000
# 4                      2024-03-01 09:04:50.000
#
#   Время принятия на Электросварочный стан_fact Время принятия в Буфер_plan  \
# 0                          2024-03-01 09:00:00     2024-03-01 17:50:00.000
# 1                          2024-03-01 09:01:00     2024-03-01 17:51:20.000
# 2                          2024-03-01 09:02:00     2024-03-01 17:52:30.000
# 3                          2024-03-01 09:03:00     2024-03-01 17:53:40.000
# ...

# %%
columns = data.columns[3:]

# %%
for col in columns:
  data[col] = data[col].apply(lambda x: str(x).split('.')[0])

# %%
data.head()
# Out:
#    Номер заказа  Номер трубы       Категория  \
# 0           135     15012396  Стальные трубы
# 1           135     15012403  Стальные трубы
# 2           135     15012410  Стальные трубы
# 3           135     15012417  Стальные трубы
# 4           135     15012424  Стальные трубы
#
#   Время принятия на Электросварочный стан_plan  \
# 0                          2024-03-01 09:00:10
# 1                          2024-03-01 09:01:20
# 2                          2024-03-01 09:02:30
# 3                          2024-03-01 09:03:40
# 4                          2024-03-01 09:04:50
#
#   Время принятия на Электросварочный стан_fact Время принятия в Буфер_plan  \
# 0                          2024-03-01 09:00:00         2024-03-01 17:50:00
# 1                          2024-03-01 09:01:00         2024-03-01 17:51:20
# 2                          2024-03-01 09:02:00         2024-03-01 17:52:30
# 3                          2024-03-01 09:03:00         2024-03-01 17:53:40
# ...

# %%
for col in columns:
  data[col] = pd.to_datetime(data[col])
# Out:
# <ipython-input-10-11c1822621b6>:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data[col] = pd.to_datetime(data[col])
# ---------------------------------------------------------------------------
# DateParseError                            Traceback (most recent call last)
# <ipython-input-10-11c1822621b6> in <cell line: 1>()
#       1 for col in columns:
# ----> 2   data[col] = pd.to_datetime(data[col])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1106                 result = arg.tz_localize("utc")
#    1107     elif isinstance(arg, ABCSeries):
# -> 1108         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1109         if not cache_array.empty:
# ...
